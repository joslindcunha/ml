# %%
#Diagnosis of heart patients using standard Heart Disease Data Set
import numpy as np
from urllib.request import urlopen
import pandas as pd

# %%
#Importing Heart Disease Data Set and Customizing
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
np.set_printoptions(threshold=np.nan)
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names)
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %%
#Modeling Heart Disease Data
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator

model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex', 'trestbps'), ('sex', 'trestbps'), 
                       ('exang', 'trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),
                      ('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])

# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
print("Nodes of the Model:\n",model.nodes())
print("Edges of the model:\n",model.edges())
print("CPDS for Cholestrol:\n",model.get_cpds('chol'))#Cpds for other attributes can be printed in a similar way
print("Models independencies:\n",model.get_independencies())
# Out:
# Nodes of the Model:
#  ['age', 'trestbps', 'fbs', 'sex', 'exang', 'heartdisease', 'restecg', 'thalach', 'chol']
# Edges of the model:
#  [('age', 'trestbps'), ('age', 'fbs'), ('trestbps', 'heartdisease'), ('fbs', 'heartdisease'), ('sex', 'trestbps'), ('exang', 'trestbps'), ('heartdisease', 'restecg'), ('heartdisease', 'thalach'), ('heartdisease', 'chol')]
# CPDS for Cholestrol:
#  ╒══════════════╤══════════════════════╤══════════════════════╕
# │ heartdisease │ heartdisease(0)      │ heartdisease(1)      │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(100)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(117)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(129)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(132)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(147)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(156)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(160)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(161)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(163)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(164)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(166)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(167)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(168)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(171)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(172)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(173)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(175)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(179)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(180)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(182)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(184)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(186)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(187)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(188)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(190)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(193)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(194)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(195)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(196)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(198)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(200)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(201)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(202)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(204)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(205)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(206)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(207)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(208)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(209)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(210)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(211)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(212)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(213)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(214)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(215)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(216)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(217)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(218)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(219)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(220)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(221)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(222)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(223)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(224)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(225)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(226)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(227)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(228)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(229)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(230)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(231)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(233)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(234)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(237)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(238)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(240)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(241)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(242)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(243)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(245)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(246)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(247)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(248)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(249)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(250)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(251)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(253)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(254)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(255)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(256)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(257)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(259)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(260)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(263)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(264)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(265)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(266)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(267)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(268)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(269)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(270)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(271)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(272)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(273)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(274)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(275)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(276)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(277)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(279)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(280)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(281)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(282)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(283)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(284)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(285)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(287)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(288)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(289)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(290)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(291)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(292)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(294)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(295)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(297)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(298)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(303)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(305)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(306)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(307)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(308)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(309)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(312)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(315)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(318)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(320)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(326)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(328)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(329)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(331)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(336)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(338)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(339)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(340)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(341)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(342)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(344)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(347)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(355)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(358)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(365)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(388)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(392)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(393)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(394)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(404)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(412)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(466)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(468)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(491)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(518)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(529)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(603)    │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(85)     │ 0.006493506493506494 │ 0.006493506493506494 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(?)      │ 0.006493506493506494 │ 0.006493506493506494 │
# ╘══════════════╧══════════════════════╧══════════════════════╛
# Models independencies:
#  (age _|_ sex, exang)
# (age _|_ restecg, chol, thalach | heartdisease)
# (age _|_ exang | sex)
# (age _|_ sex, exang | fbs)
# (age _|_ sex | exang)
# (age _|_ thalach, chol | restecg, heartdisease)
# (age _|_ restecg, thalach | heartdisease, chol)
# (age _|_ restecg, chol | thalach, heartdisease)
# (age _|_ restecg, chol, thalach | heartdisease, trestbps)
# (age _|_ restecg, chol, thalach | heartdisease, sex)
# (age _|_ restecg, chol, thalach | heartdisease, fbs)
# (age _|_ restecg, chol, thalach | heartdisease, exang)
# (age _|_ restecg, heartdisease, chol, thalach | fbs, trestbps)
# (age _|_ exang | sex, fbs)
# (age _|_ sex | fbs, exang)
# (age _|_ thalach | restecg, heartdisease, chol)
# (age _|_ chol | restecg, heartdisease, thalach)
# (age _|_ thalach, chol | restecg, heartdisease, trestbps)
# (age _|_ thalach, chol | restecg, heartdisease, sex)
# (age _|_ thalach, chol | restecg, heartdisease, fbs)
# (age _|_ thalach, chol | restecg, heartdisease, exang)
# (age _|_ thalach, heartdisease, chol | restecg, fbs, trestbps)
# (age _|_ restecg | thalach, heartdisease, chol)
# (age _|_ restecg, thalach | heartdisease, chol, trestbps)
# (age _|_ restecg, thalach | heartdisease, chol, sex)
# (age _|_ restecg, thalach | heartdisease, chol, fbs)
# (age _|_ restecg, thalach | heartdisease, chol, exang)
# (age _|_ restecg, chol | thalach, heartdisease, trestbps)
# (age _|_ restecg, chol | thalach, heartdisease, sex)
# (age _|_ restecg, chol | thalach, heartdisease, fbs)
# (age _|_ restecg, chol | thalach, heartdisease, exang)
# (age _|_ restecg, chol, thalach | heartdisease, sex, trestbps)
# (age _|_ restecg, chol, thalach | heartdisease, fbs, trestbps)
# (age _|_ restecg, chol, thalach | heartdisease, trestbps, exang)
# (age _|_ restecg, chol, thalach | heartdisease, sex, fbs)
# (age _|_ restecg, chol, thalach | heartdisease, sex, exang)
# (age _|_ restecg, chol, thalach | heartdisease, fbs, exang)
# (age _|_ restecg, heartdisease, thalach | chol, fbs, trestbps)
# (age _|_ restecg, heartdisease, chol | thalach, fbs, trestbps)
# (age _|_ restecg, heartdisease, chol, thalach | fbs, sex, trestbps)
# (age _|_ restecg, heartdisease, chol, thalach | fbs, trestbps, exang)
# (age _|_ thalach | restecg, heartdisease, chol, trestbps)
# (age _|_ thalach | restecg, heartdisease, chol, sex)
# (age _|_ thalach | restecg, heartdisease, chol, fbs)
# (age _|_ thalach | restecg, heartdisease, chol, exang)
# (age _|_ chol | restecg, heartdisease, thalach, trestbps)
# (age _|_ chol | restecg, heartdisease, thalach, sex)
# (age _|_ chol | restecg, heartdisease, thalach, fbs)
# (age _|_ chol | restecg, heartdisease, thalach, exang)
# (age _|_ thalach, chol | restecg, heartdisease, sex, trestbps)
# (age _|_ thalach, chol | restecg, heartdisease, fbs, trestbps)
# (age _|_ thalach, chol | restecg, heartdisease, trestbps, exang)
# (age _|_ thalach, chol | restecg, heartdisease, sex, fbs)
# (age _|_ thalach, chol | restecg, heartdisease, sex, exang)
# (age _|_ thalach, chol | restecg, heartdisease, fbs, exang)
# (age _|_ thalach, heartdisease | restecg, chol, fbs, trestbps)
# (age _|_ heartdisease, chol | restecg, fbs, thalach, trestbps)
# (age _|_ thalach, heartdisease, chol | restecg, fbs, sex, trestbps)
# (age _|_ thalach, heartdisease, chol | restecg, fbs, trestbps, exang)
# (age _|_ restecg | thalach, heartdisease, chol, trestbps)
# (age _|_ restecg | thalach, heartdisease, chol, sex)
# (age _|_ restecg | thalach, heartdisease, chol, fbs)
# (age _|_ restecg | thalach, heartdisease, chol, exang)
# (age _|_ restecg, thalach | heartdisease, chol, sex, trestbps)
# (age _|_ restecg, thalach | heartdisease, chol, fbs, trestbps)
# (age _|_ restecg, thalach | heartdisease, chol, trestbps, exang)
# (age _|_ restecg, thalach | heartdisease, chol, sex, fbs)
# (age _|_ restecg, thalach | heartdisease, chol, sex, exang)
# (age _|_ restecg, thalach | heartdisease, chol, fbs, exang)
# (age _|_ restecg, chol | thalach, heartdisease, sex, trestbps)
# (age _|_ restecg, chol | thalach, heartdisease, fbs, trestbps)
# (age _|_ restecg, chol | thalach, heartdisease, trestbps, exang)
# (age _|_ restecg, chol | thalach, heartdisease, sex, fbs)
# (age _|_ restecg, chol | thalach, heartdisease, sex, exang)
# (age _|_ restecg, chol | thalach, heartdisease, fbs, exang)
# (age _|_ restecg, chol, thalach | fbs, heartdisease, sex, trestbps)
# (age _|_ restecg, chol, thalach | heartdisease, sex, trestbps, exang)
# (age _|_ restecg, chol, thalach | heartdisease, fbs, trestbps, exang)
# (age _|_ restecg, chol, thalach | heartdisease, sex, fbs, exang)
# (age _|_ restecg, heartdisease | thalach, chol, fbs, trestbps)
# (age _|_ restecg, heartdisease, thalach | fbs, chol, sex, trestbps)
# (age _|_ restecg, heartdisease, thalach | chol, fbs, trestbps, exang)
# (age _|_ restecg, heartdisease, chol | thalach, fbs, sex, trestbps)
# (age _|_ restecg, heartdisease, chol | thalach, fbs, trestbps, exang)
# (age _|_ restecg, heartdisease, chol, thalach | fbs, sex, trestbps, exang)
# (age _|_ thalach | restecg, heartdisease, chol, trestbps, sex)
# (age _|_ thalach | restecg, heartdisease, chol, trestbps, fbs)
# (age _|_ thalach | restecg, heartdisease, chol, trestbps, exang)
# (age _|_ thalach | restecg, heartdisease, chol, sex, fbs)
# (age _|_ thalach | restecg, heartdisease, chol, sex, exang)
# (age _|_ thalach | restecg, heartdisease, chol, fbs, exang)
# (age _|_ chol | restecg, heartdisease, thalach, trestbps, sex)
# (age _|_ chol | restecg, heartdisease, thalach, trestbps, fbs)
# (age _|_ chol | restecg, heartdisease, thalach, trestbps, exang)
# (age _|_ chol | restecg, heartdisease, thalach, sex, fbs)
# (age _|_ chol | restecg, heartdisease, thalach, sex, exang)
# (age _|_ chol | restecg, heartdisease, thalach, fbs, exang)
# (age _|_ thalach, chol | restecg, heartdisease, trestbps, sex, fbs)
# (age _|_ thalach, chol | restecg, heartdisease, trestbps, sex, exang)
# (age _|_ thalach, chol | restecg, heartdisease, trestbps, fbs, exang)
# (age _|_ thalach, chol | restecg, heartdisease, sex, fbs, exang)
# (age _|_ heartdisease | restecg, chol, thalach, trestbps, fbs)
# (age _|_ thalach, heartdisease | restecg, chol, trestbps, sex, fbs)
# (age _|_ thalach, heartdisease | restecg, chol, trestbps, fbs, exang)
# (age _|_ heartdisease, chol | restecg, thalach, trestbps, sex, fbs)
# (age _|_ heartdisease, chol | restecg, thalach, trestbps, fbs, exang)
# (age _|_ thalach, heartdisease, chol | restecg, trestbps, sex, fbs, exang)
# (age _|_ restecg | heartdisease, chol, thalach, trestbps, sex)
# (age _|_ restecg | heartdisease, chol, thalach, trestbps, fbs)
# (age _|_ restecg | heartdisease, chol, thalach, trestbps, exang)
# (age _|_ restecg | heartdisease, chol, thalach, sex, fbs)
# (age _|_ restecg | heartdisease, chol, thalach, sex, exang)
# (age _|_ restecg | heartdisease, chol, thalach, fbs, exang)
# (age _|_ restecg, thalach | heartdisease, chol, trestbps, sex, fbs)
# (age _|_ restecg, thalach | heartdisease, chol, trestbps, sex, exang)
# (age _|_ restecg, thalach | heartdisease, chol, trestbps, fbs, exang)
# (age _|_ restecg, thalach | heartdisease, chol, sex, fbs, exang)
# (age _|_ restecg, chol | heartdisease, thalach, trestbps, sex, fbs)
# (age _|_ restecg, chol | heartdisease, thalach, trestbps, sex, exang)
# (age _|_ restecg, chol | heartdisease, thalach, trestbps, fbs, exang)
# (age _|_ restecg, chol | heartdisease, thalach, sex, fbs, exang)
# (age _|_ restecg, chol, thalach | heartdisease, trestbps, sex, fbs, exang)
# (age _|_ restecg, heartdisease | chol, thalach, trestbps, sex, fbs)
# (age _|_ restecg, heartdisease | chol, thalach, trestbps, fbs, exang)
# (age _|_ restecg, heartdisease, thalach | chol, trestbps, sex, fbs, exang)
# (age _|_ restecg, heartdisease, chol | thalach, trestbps, sex, fbs, exang)
# (age _|_ thalach | restecg, heartdisease, chol, trestbps, sex, fbs)
# (age _|_ thalach | restecg, heartdisease, chol, trestbps, sex, exang)
# (age _|_ thalach | restecg, heartdisease, chol, trestbps, fbs, exang)
# (age _|_ thalach | restecg, heartdisease, chol, sex, fbs, exang)
# (age _|_ chol | restecg, heartdisease, thalach, trestbps, sex, fbs)
# (age _|_ chol | restecg, heartdisease, thalach, trestbps, sex, exang)
# (age _|_ chol | restecg, heartdisease, thalach, trestbps, fbs, exang)
# (age _|_ chol | restecg, heartdisease, thalach, sex, fbs, exang)
# (age _|_ thalach, chol | restecg, heartdisease, trestbps, sex, fbs, exang)
# (age _|_ heartdisease | restecg, chol, thalach, trestbps, sex, fbs)
# (age _|_ heartdisease | restecg, chol, thalach, trestbps, fbs, exang)
# (age _|_ thalach, heartdisease | restecg, chol, trestbps, sex, fbs, exang)
# (age _|_ heartdisease, chol | restecg, thalach, trestbps, sex, fbs, exang)
# (age _|_ restecg | heartdisease, chol, thalach, trestbps, sex, fbs)
# (age _|_ restecg | heartdisease, chol, thalach, trestbps, sex, exang)
# (age _|_ restecg | heartdisease, chol, thalach, trestbps, fbs, exang)
# (age _|_ restecg | heartdisease, chol, thalach, sex, fbs, exang)
# (age _|_ restecg, thalach | heartdisease, chol, trestbps, sex, fbs, exang)
# (age _|_ restecg, chol | heartdisease, thalach, trestbps, sex, fbs, exang)
# (age _|_ restecg, heartdisease | chol, thalach, trestbps, sex, fbs, exang)
# (age _|_ thalach | restecg, heartdisease, chol, trestbps, sex, fbs, exang)
# (age _|_ chol | restecg, heartdisease, thalach, trestbps, sex, fbs, exang)
# (age _|_ heartdisease | restecg, chol, thalach, trestbps, sex, fbs, exang)
# (age _|_ restecg | heartdisease, chol, thalach, trestbps, sex, fbs, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ thalach, chol | restecg, heartdisease)
# (trestbps _|_ restecg, thalach | heartdisease, chol)
# (trestbps _|_ restecg, chol | thalach, heartdisease)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age)
# (trestbps _|_ restecg, chol, thalach | heartdisease, sex)
# (trestbps _|_ restecg, chol, thalach | heartdisease, fbs)
# (trestbps _|_ restecg, chol, thalach | heartdisease, exang)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ thalach | restecg, heartdisease, chol)
# (trestbps _|_ chol | restecg, heartdisease, thalach)
# (trestbps _|_ thalach, chol | restecg, heartdisease, age)
# (trestbps _|_ thalach, chol | restecg, heartdisease, sex)
# (trestbps _|_ thalach, chol | restecg, heartdisease, fbs)
# (trestbps _|_ thalach, chol | restecg, heartdisease, exang)
# (trestbps _|_ restecg | thalach, heartdisease, chol)
# (trestbps _|_ restecg, thalach | age, heartdisease, chol)
# (trestbps _|_ restecg, thalach | heartdisease, chol, sex)
# (trestbps _|_ restecg, thalach | heartdisease, chol, fbs)
# (trestbps _|_ restecg, thalach | heartdisease, chol, exang)
# (trestbps _|_ restecg, chol | thalach, heartdisease, age)
# (trestbps _|_ restecg, chol | thalach, heartdisease, sex)
# (trestbps _|_ restecg, chol | thalach, heartdisease, fbs)
# (trestbps _|_ restecg, chol | thalach, heartdisease, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, sex)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, fbs)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, sex, fbs)
# (trestbps _|_ restecg, chol, thalach | heartdisease, sex, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, fbs, exang)
# (trestbps _|_ fbs | age, sex, exang)
# (trestbps _|_ thalach | restecg, age, heartdisease, chol)
# (trestbps _|_ thalach | restecg, heartdisease, chol, sex)
# (trestbps _|_ thalach | restecg, heartdisease, chol, fbs)
# (trestbps _|_ thalach | restecg, heartdisease, chol, exang)
# (trestbps _|_ chol | restecg, heartdisease, age, thalach)
# (trestbps _|_ chol | restecg, heartdisease, thalach, sex)
# (trestbps _|_ chol | restecg, heartdisease, thalach, fbs)
# (trestbps _|_ chol | restecg, heartdisease, thalach, exang)
# (trestbps _|_ thalach, chol | restecg, heartdisease, age, sex)
# (trestbps _|_ thalach, chol | restecg, heartdisease, age, fbs)
# (trestbps _|_ thalach, chol | restecg, heartdisease, age, exang)
# (trestbps _|_ thalach, chol | restecg, heartdisease, sex, fbs)
# (trestbps _|_ thalach, chol | restecg, heartdisease, sex, exang)
# (trestbps _|_ thalach, chol | restecg, heartdisease, fbs, exang)
# (trestbps _|_ restecg | thalach, age, heartdisease, chol)
# (trestbps _|_ restecg | thalach, heartdisease, chol, sex)
# (trestbps _|_ restecg | thalach, heartdisease, chol, fbs)
# (trestbps _|_ restecg | thalach, heartdisease, chol, exang)
# (trestbps _|_ restecg, thalach | age, heartdisease, chol, sex)
# (trestbps _|_ restecg, thalach | age, heartdisease, chol, fbs)
# (trestbps _|_ restecg, thalach | age, heartdisease, chol, exang)
# (trestbps _|_ restecg, thalach | heartdisease, chol, sex, fbs)
# (trestbps _|_ restecg, thalach | heartdisease, chol, sex, exang)
# (trestbps _|_ restecg, thalach | heartdisease, chol, fbs, exang)
# (trestbps _|_ restecg, chol | thalach, heartdisease, age, sex)
# (trestbps _|_ restecg, chol | thalach, heartdisease, age, fbs)
# (trestbps _|_ restecg, chol | thalach, heartdisease, age, exang)
# (trestbps _|_ restecg, chol | thalach, heartdisease, sex, fbs)
# (trestbps _|_ restecg, chol | thalach, heartdisease, sex, exang)
# (trestbps _|_ restecg, chol | thalach, heartdisease, fbs, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, sex, fbs)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, sex, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, fbs, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, sex, fbs, exang)
# (trestbps _|_ thalach | restecg, heartdisease, chol, age, sex)
# (trestbps _|_ thalach | restecg, heartdisease, chol, age, fbs)
# (trestbps _|_ thalach | restecg, heartdisease, chol, age, exang)
# (trestbps _|_ thalach | restecg, heartdisease, chol, sex, fbs)
# (trestbps _|_ thalach | restecg, heartdisease, chol, sex, exang)
# (trestbps _|_ thalach | restecg, heartdisease, chol, fbs, exang)
# (trestbps _|_ chol | restecg, heartdisease, thalach, age, sex)
# (trestbps _|_ chol | restecg, heartdisease, thalach, age, fbs)
# (trestbps _|_ chol | restecg, heartdisease, thalach, age, exang)
# (trestbps _|_ chol | restecg, heartdisease, thalach, sex, fbs)
# (trestbps _|_ chol | restecg, heartdisease, thalach, sex, exang)
# (trestbps _|_ chol | restecg, heartdisease, thalach, fbs, exang)
# (trestbps _|_ thalach, chol | restecg, heartdisease, age, sex, fbs)
# (trestbps _|_ thalach, chol | restecg, heartdisease, age, sex, exang)
# (trestbps _|_ thalach, chol | restecg, heartdisease, age, fbs, exang)
# (trestbps _|_ thalach, chol | restecg, heartdisease, sex, fbs, exang)
# (trestbps _|_ restecg | heartdisease, chol, thalach, age, sex)
# (trestbps _|_ restecg | heartdisease, chol, thalach, age, fbs)
# (trestbps _|_ restecg | heartdisease, chol, thalach, age, exang)
# (trestbps _|_ restecg | heartdisease, chol, thalach, sex, fbs)
# (trestbps _|_ restecg | heartdisease, chol, thalach, sex, exang)
# (trestbps _|_ restecg | heartdisease, chol, thalach, fbs, exang)
# (trestbps _|_ restecg, thalach | heartdisease, chol, age, sex, fbs)
# (trestbps _|_ restecg, thalach | heartdisease, chol, age, sex, exang)
# (trestbps _|_ restecg, thalach | heartdisease, chol, age, fbs, exang)
# (trestbps _|_ restecg, thalach | heartdisease, chol, sex, fbs, exang)
# (trestbps _|_ restecg, chol | heartdisease, thalach, age, sex, fbs)
# (trestbps _|_ restecg, chol | heartdisease, thalach, age, sex, exang)
# (trestbps _|_ restecg, chol | heartdisease, thalach, age, fbs, exang)
# (trestbps _|_ restecg, chol | heartdisease, thalach, sex, fbs, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, sex, fbs, exang)
# (trestbps _|_ thalach | restecg, heartdisease, chol, age, sex, fbs)
# (trestbps _|_ thalach | restecg, heartdisease, chol, age, sex, exang)
# (trestbps _|_ thalach | restecg, heartdisease, chol, age, fbs, exang)
# (trestbps _|_ thalach | restecg, heartdisease, chol, sex, fbs, exang)
# (trestbps _|_ chol | restecg, heartdisease, thalach, age, sex, fbs)
# (trestbps _|_ chol | restecg, heartdisease, thalach, age, sex, exang)
# (trestbps _|_ chol | restecg, heartdisease, thalach, age, fbs, exang)
# (trestbps _|_ chol | restecg, heartdisease, thalach, sex, fbs, exang)
# (trestbps _|_ thalach, chol | restecg, heartdisease, age, sex, fbs, exang)
# (trestbps _|_ restecg | heartdisease, chol, thalach, age, sex, fbs)
# (trestbps _|_ restecg | heartdisease, chol, thalach, age, sex, exang)
# (trestbps _|_ restecg | heartdisease, chol, thalach, age, fbs, exang)
# (trestbps _|_ restecg | heartdisease, chol, thalach, sex, fbs, exang)
# (trestbps _|_ restecg, thalach | heartdisease, chol, age, sex, fbs, exang)
# (trestbps _|_ restecg, chol | heartdisease, thalach, age, sex, fbs, exang)
# (trestbps _|_ thalach | restecg, heartdisease, chol, age, sex, fbs, exang)
# (trestbps _|_ chol | restecg, heartdisease, thalach, age, sex, fbs, exang)
# (trestbps _|_ restecg | heartdisease, chol, thalach, age, sex, fbs, exang)
# (fbs _|_ sex, exang)
# (fbs _|_ restecg, chol, thalach | heartdisease)
# (fbs _|_ sex, trestbps, exang | age)
# (fbs _|_ exang | sex)
# (fbs _|_ sex | exang)
# (fbs _|_ thalach, chol | restecg, heartdisease)
# (fbs _|_ restecg, thalach | heartdisease, chol)
# (fbs _|_ restecg, chol | thalach, heartdisease)
# (fbs _|_ restecg, chol, thalach | heartdisease, trestbps)
# (fbs _|_ restecg, chol, thalach | heartdisease, age)
# (fbs _|_ restecg, chol, thalach | heartdisease, sex)
# (fbs _|_ restecg, chol, thalach | heartdisease, exang)
# (fbs _|_ sex, exang | age, trestbps)
# (fbs _|_ trestbps, exang | age, sex)
# (fbs _|_ sex, trestbps | age, exang)
# (fbs _|_ thalach | restecg, heartdisease, chol)
# (fbs _|_ chol | restecg, heartdisease, thalach)
# (fbs _|_ thalach, chol | restecg, heartdisease, trestbps)
# (fbs _|_ thalach, chol | restecg, heartdisease, age)
# (fbs _|_ thalach, chol | restecg, heartdisease, sex)
# (fbs _|_ thalach, chol | restecg, heartdisease, exang)
# (fbs _|_ sex, exang | restecg, age, trestbps)
# (fbs _|_ restecg | thalach, heartdisease, chol)
# (fbs _|_ restecg, thalach | heartdisease, chol, trestbps)
# (fbs _|_ restecg, thalach | age, heartdisease, chol)
# (fbs _|_ restecg, thalach | heartdisease, chol, sex)
# (fbs _|_ restecg, thalach | heartdisease, chol, exang)
# (fbs _|_ restecg, chol | thalach, heartdisease, trestbps)
# (fbs _|_ restecg, chol | thalach, heartdisease, age)
# (fbs _|_ restecg, chol | thalach, heartdisease, sex)
# (fbs _|_ restecg, chol | thalach, heartdisease, exang)
# (fbs _|_ restecg, chol, sex, thalach, exang | heartdisease, age, trestbps)
# (fbs _|_ restecg, chol, thalach | heartdisease, sex, trestbps)
# (fbs _|_ restecg, chol, thalach | heartdisease, trestbps, exang)
# (fbs _|_ restecg, chol, thalach | heartdisease, age, sex)
# (fbs _|_ restecg, chol, thalach | heartdisease, age, exang)
# (fbs _|_ restecg, chol, thalach | heartdisease, sex, exang)
# (fbs _|_ sex, exang | chol, age, trestbps)
# (fbs _|_ sex, exang | thalach, age, trestbps)
# (fbs _|_ exang | age, sex, trestbps)
# (fbs _|_ sex | age, trestbps, exang)
# (fbs _|_ trestbps | age, sex, exang)
# (fbs _|_ thalach | restecg, heartdisease, chol, trestbps)
# (fbs _|_ thalach | restecg, age, heartdisease, chol)
# (fbs _|_ thalach | restecg, heartdisease, chol, sex)
# (fbs _|_ thalach | restecg, heartdisease, chol, exang)
# (fbs _|_ chol | restecg, heartdisease, thalach, trestbps)
# (fbs _|_ chol | restecg, heartdisease, age, thalach)
# (fbs _|_ chol | restecg, heartdisease, thalach, sex)
# (fbs _|_ chol | restecg, heartdisease, thalach, exang)
# (fbs _|_ thalach, chol, sex, exang | restecg, heartdisease, age, trestbps)
# (fbs _|_ thalach, chol | restecg, heartdisease, sex, trestbps)
# (fbs _|_ thalach, chol | restecg, heartdisease, trestbps, exang)
# (fbs _|_ thalach, chol | restecg, heartdisease, age, sex)
# (fbs _|_ thalach, chol | restecg, heartdisease, age, exang)
# (fbs _|_ thalach, chol | restecg, heartdisease, sex, exang)
# (fbs _|_ sex, exang | restecg, chol, age, trestbps)
# (fbs _|_ sex, exang | restecg, age, thalach, trestbps)
# (fbs _|_ exang | restecg, age, sex, trestbps)
# (fbs _|_ sex | restecg, age, trestbps, exang)
# (fbs _|_ restecg | thalach, heartdisease, chol, trestbps)
# (fbs _|_ restecg | thalach, age, heartdisease, chol)
# (fbs _|_ restecg | thalach, heartdisease, chol, sex)
# (fbs _|_ restecg | thalach, heartdisease, chol, exang)
# (fbs _|_ restecg, thalach, sex, exang | age, heartdisease, chol, trestbps)
# (fbs _|_ restecg, thalach | heartdisease, chol, sex, trestbps)
# (fbs _|_ restecg, thalach | heartdisease, chol, trestbps, exang)
# (fbs _|_ restecg, thalach | age, heartdisease, chol, sex)
# (fbs _|_ restecg, thalach | age, heartdisease, chol, exang)
# (fbs _|_ restecg, thalach | heartdisease, chol, sex, exang)
# (fbs _|_ restecg, chol, sex, exang | thalach, heartdisease, age, trestbps)
# (fbs _|_ restecg, chol | thalach, heartdisease, sex, trestbps)
# (fbs _|_ restecg, chol | thalach, heartdisease, trestbps, exang)
# (fbs _|_ restecg, chol | thalach, heartdisease, age, sex)
# (fbs _|_ restecg, chol | thalach, heartdisease, age, exang)
# (fbs _|_ restecg, chol | thalach, heartdisease, sex, exang)
# (fbs _|_ restecg, chol, thalach, exang | heartdisease, age, sex, trestbps)
# (fbs _|_ restecg, chol, thalach, sex | heartdisease, age, trestbps, exang)
# (fbs _|_ restecg, chol, thalach | heartdisease, sex, trestbps, exang)
# (fbs _|_ restecg, chol, thalach | heartdisease, age, sex, exang)
# (fbs _|_ sex, exang | thalach, chol, age, trestbps)
# (fbs _|_ exang | chol, age, sex, trestbps)
# (fbs _|_ sex | chol, age, trestbps, exang)
# (fbs _|_ exang | thalach, age, sex, trestbps)
# (fbs _|_ sex | thalach, age, trestbps, exang)
# (fbs _|_ thalach, sex, exang | restecg, heartdisease, chol, trestbps, age)
# (fbs _|_ thalach | restecg, heartdisease, chol, trestbps, sex)
# (fbs _|_ thalach | restecg, heartdisease, chol, trestbps, exang)
# (fbs _|_ thalach | restecg, heartdisease, chol, age, sex)
# (fbs _|_ thalach | restecg, heartdisease, chol, age, exang)
# (fbs _|_ thalach | restecg, heartdisease, chol, sex, exang)
# (fbs _|_ chol, sex, exang | restecg, heartdisease, thalach, trestbps, age)
# (fbs _|_ chol | restecg, heartdisease, thalach, trestbps, sex)
# (fbs _|_ chol | restecg, heartdisease, thalach, trestbps, exang)
# (fbs _|_ chol | restecg, heartdisease, thalach, age, sex)
# (fbs _|_ chol | restecg, heartdisease, thalach, age, exang)
# (fbs _|_ chol | restecg, heartdisease, thalach, sex, exang)
# (fbs _|_ thalach, chol, exang | restecg, heartdisease, trestbps, age, sex)
# (fbs _|_ thalach, chol, sex | restecg, heartdisease, trestbps, age, exang)
# (fbs _|_ thalach, chol | restecg, heartdisease, trestbps, sex, exang)
# (fbs _|_ thalach, chol | restecg, heartdisease, age, sex, exang)
# (fbs _|_ sex, exang | restecg, chol, thalach, trestbps, age)
# (fbs _|_ exang | restecg, chol, trestbps, age, sex)
# (fbs _|_ sex | restecg, chol, trestbps, age, exang)
# (fbs _|_ exang | restecg, thalach, trestbps, age, sex)
# (fbs _|_ sex | restecg, thalach, trestbps, age, exang)
# (fbs _|_ restecg, sex, exang | heartdisease, chol, thalach, trestbps, age)
# (fbs _|_ restecg | heartdisease, chol, thalach, trestbps, sex)
# (fbs _|_ restecg | heartdisease, chol, thalach, trestbps, exang)
# (fbs _|_ restecg | heartdisease, chol, thalach, age, sex)
# (fbs _|_ restecg | heartdisease, chol, thalach, age, exang)
# (fbs _|_ restecg | heartdisease, chol, thalach, sex, exang)
# (fbs _|_ restecg, thalach, exang | heartdisease, chol, trestbps, age, sex)
# (fbs _|_ restecg, thalach, sex | heartdisease, chol, trestbps, age, exang)
# (fbs _|_ restecg, thalach | heartdisease, chol, trestbps, sex, exang)
# (fbs _|_ restecg, thalach | heartdisease, chol, age, sex, exang)
# (fbs _|_ restecg, chol, exang | heartdisease, thalach, trestbps, age, sex)
# (fbs _|_ restecg, chol, sex | heartdisease, thalach, trestbps, age, exang)
# (fbs _|_ restecg, chol | heartdisease, thalach, trestbps, sex, exang)
# (fbs _|_ restecg, chol | heartdisease, thalach, age, sex, exang)
# (fbs _|_ restecg, chol, thalach | heartdisease, trestbps, age, sex, exang)
# (fbs _|_ exang | chol, thalach, trestbps, age, sex)
# (fbs _|_ sex | chol, thalach, trestbps, age, exang)
# (fbs _|_ sex, exang | restecg, heartdisease, chol, thalach, trestbps, age)
# (fbs _|_ thalach, exang | restecg, heartdisease, chol, trestbps, age, sex)
# (fbs _|_ thalach, sex | restecg, heartdisease, chol, trestbps, age, exang)
# (fbs _|_ thalach | restecg, heartdisease, chol, trestbps, sex, exang)
# (fbs _|_ thalach | restecg, heartdisease, chol, age, sex, exang)
# (fbs _|_ chol, exang | restecg, heartdisease, thalach, trestbps, age, sex)
# (fbs _|_ chol, sex | restecg, heartdisease, thalach, trestbps, age, exang)
# (fbs _|_ chol | restecg, heartdisease, thalach, trestbps, sex, exang)
# (fbs _|_ chol | restecg, heartdisease, thalach, age, sex, exang)
# (fbs _|_ thalach, chol | restecg, heartdisease, trestbps, age, sex, exang)
# (fbs _|_ exang | restecg, chol, thalach, trestbps, age, sex)
# (fbs _|_ sex | restecg, chol, thalach, trestbps, age, exang)
# (fbs _|_ restecg, exang | heartdisease, chol, thalach, trestbps, age, sex)
# (fbs _|_ restecg, sex | heartdisease, chol, thalach, trestbps, age, exang)
# (fbs _|_ restecg | heartdisease, chol, thalach, trestbps, sex, exang)
# (fbs _|_ restecg | heartdisease, chol, thalach, age, sex, exang)
# (fbs _|_ restecg, thalach | heartdisease, chol, trestbps, age, sex, exang)
# (fbs _|_ restecg, chol | heartdisease, thalach, trestbps, age, sex, exang)
# (fbs _|_ exang | restecg, heartdisease, chol, thalach, trestbps, age, sex)
# (fbs _|_ sex | restecg, heartdisease, chol, thalach, trestbps, age, exang)
# (fbs _|_ thalach | restecg, heartdisease, chol, trestbps, age, sex, exang)
# (fbs _|_ chol | restecg, heartdisease, thalach, trestbps, age, sex, exang)
# (fbs _|_ restecg | heartdisease, chol, thalach, trestbps, age, sex, exang)
# (sex _|_ age, fbs, exang)
# (sex _|_ restecg, chol, thalach | heartdisease)
# (sex _|_ fbs, exang | age)
# (sex _|_ age, exang | fbs)
# (sex _|_ age, fbs | exang)
# (sex _|_ thalach, chol | restecg, heartdisease)
# (sex _|_ restecg, thalach | heartdisease, chol)
# (sex _|_ restecg, chol | thalach, heartdisease)
# (sex _|_ restecg, chol, thalach | heartdisease, trestbps)
# (sex _|_ restecg, chol, thalach | heartdisease, age)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs)
# (sex _|_ restecg, chol, thalach | heartdisease, exang)
# (sex _|_ restecg, heartdisease, chol, thalach, fbs | age, trestbps)
# (sex _|_ restecg, heartdisease, chol, thalach | fbs, trestbps)
# (sex _|_ exang | age, fbs)
# (sex _|_ fbs | age, exang)
# (sex _|_ age | fbs, exang)
# (sex _|_ thalach | restecg, heartdisease, chol)
# (sex _|_ chol | restecg, heartdisease, thalach)
# (sex _|_ thalach, chol | restecg, heartdisease, trestbps)
# (sex _|_ thalach, chol | restecg, heartdisease, age)
# (sex _|_ thalach, chol | restecg, heartdisease, fbs)
# (sex _|_ thalach, chol | restecg, heartdisease, exang)
# (sex _|_ thalach, heartdisease, chol, fbs | restecg, age, trestbps)
# (sex _|_ thalach, heartdisease, chol | restecg, fbs, trestbps)
# (sex _|_ restecg | thalach, heartdisease, chol)
# (sex _|_ restecg, thalach | heartdisease, chol, trestbps)
# (sex _|_ restecg, thalach | age, heartdisease, chol)
# (sex _|_ restecg, thalach | heartdisease, chol, fbs)
# (sex _|_ restecg, thalach | heartdisease, chol, exang)
# (sex _|_ restecg, chol | thalach, heartdisease, trestbps)
# (sex _|_ restecg, chol | thalach, heartdisease, age)
# (sex _|_ restecg, chol | thalach, heartdisease, fbs)
# (sex _|_ restecg, chol | thalach, heartdisease, exang)
# (sex _|_ restecg, chol, thalach, fbs | heartdisease, age, trestbps)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs, trestbps)
# (sex _|_ restecg, chol, thalach | heartdisease, trestbps, exang)
# (sex _|_ restecg, chol, thalach | heartdisease, age, fbs)
# (sex _|_ restecg, chol, thalach | heartdisease, age, exang)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs, exang)
# (sex _|_ restecg, heartdisease, thalach, fbs | chol, age, trestbps)
# (sex _|_ restecg, heartdisease, thalach | chol, fbs, trestbps)
# (sex _|_ restecg, heartdisease, chol, fbs | thalach, age, trestbps)
# (sex _|_ restecg, heartdisease, chol | thalach, fbs, trestbps)
# (sex _|_ restecg, heartdisease, chol, thalach | fbs, age, trestbps)
# (sex _|_ restecg, heartdisease, chol, thalach, fbs | age, trestbps, exang)
# (sex _|_ restecg, heartdisease, chol, thalach | fbs, trestbps, exang)
# (sex _|_ thalach | restecg, heartdisease, chol, trestbps)
# (sex _|_ thalach | restecg, age, heartdisease, chol)
# (sex _|_ thalach | restecg, heartdisease, chol, fbs)
# (sex _|_ thalach | restecg, heartdisease, chol, exang)
# (sex _|_ chol | restecg, heartdisease, thalach, trestbps)
# ...
# (thalach _|_ chol, age, sex | restecg, heartdisease, trestbps, fbs, exang)
# (thalach _|_ chol, trestbps, exang | restecg, heartdisease, age, sex, fbs)
# (thalach _|_ trestbps, chol, fbs | restecg, heartdisease, age, sex, exang)
# (thalach _|_ chol, sex, trestbps | restecg, heartdisease, age, fbs, exang)
# (thalach _|_ chol, age, trestbps | restecg, heartdisease, sex, fbs, exang)
# (thalach _|_ exang | restecg, chol, trestbps, age, sex)
# (thalach _|_ sex, exang | restecg, chol, trestbps, age, fbs)
# (thalach _|_ sex | restecg, chol, trestbps, age, exang)
# (thalach _|_ age, exang | restecg, chol, trestbps, sex, fbs)
# (thalach _|_ age, sex | restecg, chol, trestbps, fbs, exang)
# (thalach _|_ exang | restecg, trestbps, age, sex, fbs)
# (thalach _|_ sex | restecg, trestbps, age, fbs, exang)
# (thalach _|_ age | restecg, trestbps, sex, fbs, exang)
# (thalach _|_ restecg, fbs, exang | heartdisease, chol, trestbps, age, sex)
# (thalach _|_ restecg, sex, exang | heartdisease, chol, trestbps, age, fbs)
# (thalach _|_ restecg, sex, fbs | heartdisease, chol, trestbps, age, exang)
# (thalach _|_ restecg, age, exang | heartdisease, chol, trestbps, sex, fbs)
# (thalach _|_ restecg, age, fbs | heartdisease, chol, trestbps, sex, exang)
# (thalach _|_ restecg, age, sex | heartdisease, chol, trestbps, fbs, exang)
# (thalach _|_ restecg, trestbps, exang | heartdisease, chol, age, sex, fbs)
# (thalach _|_ restecg, trestbps, fbs | heartdisease, chol, age, sex, exang)
# (thalach _|_ restecg, sex, trestbps | heartdisease, chol, age, fbs, exang)
# (thalach _|_ restecg, age, trestbps | heartdisease, chol, sex, fbs, exang)
# (thalach _|_ restecg, chol, exang | heartdisease, trestbps, age, sex, fbs)
# (thalach _|_ restecg, chol, fbs | heartdisease, trestbps, age, sex, exang)
# (thalach _|_ restecg, chol, sex | heartdisease, trestbps, age, fbs, exang)
# (thalach _|_ restecg, chol, age | heartdisease, trestbps, sex, fbs, exang)
# (thalach _|_ restecg, chol, trestbps | heartdisease, age, sex, fbs, exang)
# (thalach _|_ exang | chol, trestbps, age, sex, fbs)
# (thalach _|_ sex | chol, trestbps, age, fbs, exang)
# (thalach _|_ age | chol, trestbps, sex, fbs, exang)
# (thalach _|_ fbs, exang | restecg, heartdisease, chol, trestbps, age, sex)
# (thalach _|_ sex, exang | restecg, heartdisease, chol, trestbps, age, fbs)
# (thalach _|_ sex, fbs | restecg, heartdisease, chol, trestbps, age, exang)
# (thalach _|_ age, exang | restecg, heartdisease, chol, trestbps, sex, fbs)
# (thalach _|_ age, fbs | restecg, heartdisease, chol, trestbps, sex, exang)
# (thalach _|_ age, sex | restecg, heartdisease, chol, trestbps, fbs, exang)
# (thalach _|_ trestbps, exang | restecg, heartdisease, chol, age, sex, fbs)
# (thalach _|_ trestbps, fbs | restecg, heartdisease, chol, age, sex, exang)
# (thalach _|_ sex, trestbps | restecg, heartdisease, chol, age, fbs, exang)
# (thalach _|_ age, trestbps | restecg, heartdisease, chol, sex, fbs, exang)
# (thalach _|_ chol, exang | restecg, heartdisease, trestbps, age, sex, fbs)
# (thalach _|_ chol, fbs | restecg, heartdisease, trestbps, age, sex, exang)
# (thalach _|_ chol, sex | restecg, heartdisease, trestbps, age, fbs, exang)
# (thalach _|_ chol, age | restecg, heartdisease, trestbps, sex, fbs, exang)
# (thalach _|_ chol, trestbps | restecg, heartdisease, age, sex, fbs, exang)
# (thalach _|_ exang | restecg, chol, trestbps, age, sex, fbs)
# (thalach _|_ sex | restecg, chol, trestbps, age, fbs, exang)
# (thalach _|_ age | restecg, chol, trestbps, sex, fbs, exang)
# (thalach _|_ restecg, exang | heartdisease, chol, trestbps, age, sex, fbs)
# (thalach _|_ restecg, fbs | heartdisease, chol, trestbps, age, sex, exang)
# (thalach _|_ restecg, sex | heartdisease, chol, trestbps, age, fbs, exang)
# (thalach _|_ restecg, age | heartdisease, chol, trestbps, sex, fbs, exang)
# (thalach _|_ restecg, trestbps | heartdisease, chol, age, sex, fbs, exang)
# (thalach _|_ restecg, chol | heartdisease, trestbps, age, sex, fbs, exang)
# (thalach _|_ exang | restecg, heartdisease, chol, trestbps, age, sex, fbs)
# (thalach _|_ fbs | restecg, heartdisease, chol, trestbps, age, sex, exang)
# (thalach _|_ sex | restecg, heartdisease, chol, trestbps, age, fbs, exang)
# (thalach _|_ age | restecg, heartdisease, chol, trestbps, sex, fbs, exang)
# (thalach _|_ trestbps | restecg, heartdisease, chol, age, sex, fbs, exang)
# (thalach _|_ chol | restecg, heartdisease, trestbps, age, sex, fbs, exang)
# (thalach _|_ restecg | heartdisease, chol, trestbps, age, sex, fbs, exang)
# (chol _|_ restecg, age, sex, thalach, fbs, trestbps, exang | heartdisease)
# (chol _|_ age, sex, thalach, fbs, trestbps, exang | restecg, heartdisease)
# (chol _|_ restecg, age, sex, fbs, trestbps, exang | thalach, heartdisease)
# (chol _|_ restecg, age, sex, thalach, fbs, exang | heartdisease, trestbps)
# (chol _|_ restecg, sex, thalach, fbs, trestbps, exang | heartdisease, age)
# (chol _|_ restecg, age, thalach, fbs, trestbps, exang | heartdisease, sex)
# (chol _|_ restecg, age, sex, thalach, trestbps, exang | heartdisease, fbs)
# (chol _|_ restecg, age, sex, thalach, fbs, trestbps | heartdisease, exang)
# (chol _|_ sex, exang | age, trestbps)
# (chol _|_ age, sex, exang | fbs, trestbps)
# (chol _|_ age, sex, fbs, trestbps, exang | restecg, heartdisease, thalach)
# (chol _|_ age, sex, thalach, fbs, exang | restecg, heartdisease, trestbps)
# (chol _|_ sex, thalach, fbs, trestbps, exang | restecg, heartdisease, age)
# (chol _|_ age, thalach, fbs, trestbps, exang | restecg, heartdisease, sex)
# (chol _|_ age, sex, thalach, trestbps, exang | restecg, heartdisease, fbs)
# (chol _|_ age, sex, thalach, fbs, trestbps | restecg, heartdisease, exang)
# (chol _|_ sex, exang | restecg, age, trestbps)
# (chol _|_ age, sex, exang | restecg, fbs, trestbps)
# (chol _|_ restecg, age, sex, fbs, exang | thalach, heartdisease, trestbps)
# (chol _|_ restecg, sex, fbs, trestbps, exang | thalach, heartdisease, age)
# (chol _|_ restecg, age, fbs, trestbps, exang | thalach, heartdisease, sex)
# (chol _|_ restecg, age, sex, trestbps, exang | thalach, heartdisease, fbs)
# (chol _|_ restecg, age, sex, fbs, trestbps | thalach, heartdisease, exang)
# (chol _|_ restecg, sex, thalach, fbs, exang | heartdisease, age, trestbps)
# (chol _|_ restecg, age, thalach, fbs, exang | heartdisease, sex, trestbps)
# (chol _|_ restecg, age, sex, thalach, exang | heartdisease, fbs, trestbps)
# (chol _|_ restecg, age, sex, thalach, fbs | heartdisease, trestbps, exang)
# (chol _|_ restecg, thalach, fbs, trestbps, exang | heartdisease, age, sex)
# (chol _|_ restecg, sex, thalach, trestbps, exang | heartdisease, age, fbs)
# (chol _|_ restecg, sex, thalach, fbs, trestbps | heartdisease, age, exang)
# (chol _|_ restecg, age, thalach, trestbps, exang | heartdisease, sex, fbs)
# (chol _|_ restecg, age, thalach, fbs, trestbps | heartdisease, sex, exang)
# (chol _|_ restecg, age, sex, thalach, trestbps | heartdisease, fbs, exang)
# (chol _|_ sex, exang | thalach, age, trestbps)
# (chol _|_ age, sex, exang | thalach, fbs, trestbps)
# (chol _|_ exang | age, sex, trestbps)
# (chol _|_ sex, exang | fbs, age, trestbps)
# (chol _|_ sex | age, trestbps, exang)
# (chol _|_ age, exang | fbs, sex, trestbps)
# (chol _|_ age, sex | fbs, trestbps, exang)
# (chol _|_ age, sex, fbs, exang | restecg, heartdisease, thalach, trestbps)
# (chol _|_ trestbps, sex, fbs, exang | restecg, heartdisease, age, thalach)
# (chol _|_ trestbps, age, fbs, exang | restecg, heartdisease, thalach, sex)
# (chol _|_ age, sex, trestbps, exang | restecg, heartdisease, thalach, fbs)
# (chol _|_ trestbps, age, sex, fbs | restecg, heartdisease, thalach, exang)
# (chol _|_ thalach, sex, fbs, exang | restecg, heartdisease, age, trestbps)
# (chol _|_ thalach, age, fbs, exang | restecg, heartdisease, sex, trestbps)
# (chol _|_ thalach, age, sex, exang | restecg, heartdisease, fbs, trestbps)
# (chol _|_ thalach, age, sex, fbs | restecg, heartdisease, trestbps, exang)
# (chol _|_ thalach, trestbps, fbs, exang | restecg, heartdisease, age, sex)
# (chol _|_ thalach, sex, trestbps, exang | restecg, heartdisease, age, fbs)
# (chol _|_ thalach, trestbps, sex, fbs | restecg, heartdisease, age, exang)
# (chol _|_ thalach, age, trestbps, exang | restecg, heartdisease, sex, fbs)
# (chol _|_ thalach, trestbps, age, fbs | restecg, heartdisease, sex, exang)
# (chol _|_ thalach, age, sex, trestbps | restecg, heartdisease, fbs, exang)
# (chol _|_ sex, exang | restecg, age, thalach, trestbps)
# (chol _|_ age, sex, exang | restecg, fbs, thalach, trestbps)
# (chol _|_ exang | restecg, age, sex, trestbps)
# (chol _|_ sex, exang | restecg, fbs, age, trestbps)
# (chol _|_ sex | restecg, age, trestbps, exang)
# (chol _|_ age, exang | restecg, fbs, sex, trestbps)
# (chol _|_ age, sex | restecg, fbs, trestbps, exang)
# (chol _|_ restecg, sex, fbs, exang | thalach, heartdisease, age, trestbps)
# (chol _|_ restecg, age, fbs, exang | thalach, heartdisease, sex, trestbps)
# (chol _|_ restecg, age, sex, exang | thalach, heartdisease, fbs, trestbps)
# (chol _|_ restecg, age, sex, fbs | thalach, heartdisease, trestbps, exang)
# (chol _|_ restecg, trestbps, fbs, exang | thalach, heartdisease, age, sex)
# (chol _|_ restecg, sex, trestbps, exang | thalach, heartdisease, age, fbs)
# (chol _|_ restecg, trestbps, sex, fbs | thalach, heartdisease, age, exang)
# (chol _|_ restecg, age, trestbps, exang | thalach, heartdisease, sex, fbs)
# (chol _|_ restecg, trestbps, age, fbs | thalach, heartdisease, sex, exang)
# (chol _|_ restecg, age, sex, trestbps | thalach, heartdisease, fbs, exang)
# (chol _|_ restecg, thalach, fbs, exang | heartdisease, age, sex, trestbps)
# (chol _|_ restecg, thalach, sex, exang | heartdisease, age, fbs, trestbps)
# (chol _|_ restecg, thalach, fbs, sex | heartdisease, age, trestbps, exang)
# (chol _|_ restecg, age, thalach, exang | fbs, heartdisease, sex, trestbps)
# (chol _|_ restecg, age, thalach, fbs | heartdisease, sex, trestbps, exang)
# (chol _|_ restecg, age, thalach, sex | heartdisease, fbs, trestbps, exang)
# (chol _|_ restecg, thalach, trestbps, exang | heartdisease, age, sex, fbs)
# (chol _|_ restecg, trestbps, thalach, fbs | heartdisease, age, sex, exang)
# (chol _|_ restecg, thalach, trestbps, sex | heartdisease, age, fbs, exang)
# (chol _|_ restecg, age, thalach, trestbps | heartdisease, sex, fbs, exang)
# (chol _|_ exang | thalach, age, sex, trestbps)
# (chol _|_ sex, exang | thalach, fbs, age, trestbps)
# (chol _|_ sex | thalach, age, trestbps, exang)
# (chol _|_ age, exang | thalach, fbs, sex, trestbps)
# (chol _|_ age, sex | thalach, fbs, trestbps, exang)
# (chol _|_ exang | fbs, age, sex, trestbps)
# (chol _|_ sex | fbs, age, trestbps, exang)
# (chol _|_ age | fbs, sex, trestbps, exang)
# (chol _|_ sex, fbs, exang | restecg, heartdisease, thalach, trestbps, age)
# (chol _|_ age, fbs, exang | restecg, heartdisease, thalach, trestbps, sex)
# (chol _|_ age, sex, exang | restecg, heartdisease, thalach, trestbps, fbs)
# (chol _|_ age, sex, fbs | restecg, heartdisease, thalach, trestbps, exang)
# (chol _|_ trestbps, fbs, exang | restecg, heartdisease, thalach, age, sex)
# (chol _|_ sex, trestbps, exang | restecg, heartdisease, thalach, age, fbs)
# (chol _|_ trestbps, sex, fbs | restecg, heartdisease, thalach, age, exang)
# (chol _|_ age, trestbps, exang | restecg, heartdisease, thalach, sex, fbs)
# (chol _|_ trestbps, age, fbs | restecg, heartdisease, thalach, sex, exang)
# (chol _|_ age, sex, trestbps | restecg, heartdisease, thalach, fbs, exang)
# (chol _|_ thalach, fbs, exang | restecg, heartdisease, trestbps, age, sex)
# (chol _|_ thalach, sex, exang | restecg, heartdisease, trestbps, age, fbs)
# (chol _|_ thalach, sex, fbs | restecg, heartdisease, trestbps, age, exang)
# (chol _|_ thalach, age, exang | restecg, heartdisease, trestbps, sex, fbs)
# (chol _|_ thalach, age, fbs | restecg, heartdisease, trestbps, sex, exang)
# (chol _|_ thalach, age, sex | restecg, heartdisease, trestbps, fbs, exang)
# (chol _|_ thalach, trestbps, exang | restecg, heartdisease, age, sex, fbs)
# (chol _|_ thalach, trestbps, fbs | restecg, heartdisease, age, sex, exang)
# (chol _|_ thalach, sex, trestbps | restecg, heartdisease, age, fbs, exang)
# (chol _|_ thalach, age, trestbps | restecg, heartdisease, sex, fbs, exang)
# (chol _|_ exang | restecg, thalach, trestbps, age, sex)
# (chol _|_ sex, exang | restecg, thalach, trestbps, age, fbs)
# (chol _|_ sex | restecg, thalach, trestbps, age, exang)
# (chol _|_ age, exang | restecg, thalach, trestbps, sex, fbs)
# (chol _|_ age, sex | restecg, thalach, trestbps, fbs, exang)
# (chol _|_ exang | restecg, trestbps, age, sex, fbs)
# (chol _|_ sex | restecg, trestbps, age, fbs, exang)
# (chol _|_ age | restecg, trestbps, sex, fbs, exang)
# (chol _|_ restecg, fbs, exang | heartdisease, thalach, trestbps, age, sex)
# (chol _|_ restecg, sex, exang | heartdisease, thalach, trestbps, age, fbs)
# (chol _|_ restecg, sex, fbs | heartdisease, thalach, trestbps, age, exang)
# (chol _|_ restecg, age, exang | heartdisease, thalach, trestbps, sex, fbs)
# (chol _|_ restecg, age, fbs | heartdisease, thalach, trestbps, sex, exang)
# (chol _|_ restecg, age, sex | heartdisease, thalach, trestbps, fbs, exang)
# (chol _|_ restecg, trestbps, exang | heartdisease, thalach, age, sex, fbs)
# (chol _|_ restecg, trestbps, fbs | heartdisease, thalach, age, sex, exang)
# (chol _|_ restecg, sex, trestbps | heartdisease, thalach, age, fbs, exang)
# (chol _|_ restecg, age, trestbps | heartdisease, thalach, sex, fbs, exang)
# (chol _|_ restecg, thalach, exang | heartdisease, trestbps, age, sex, fbs)
# (chol _|_ restecg, thalach, fbs | heartdisease, trestbps, age, sex, exang)
# (chol _|_ restecg, thalach, sex | heartdisease, trestbps, age, fbs, exang)
# (chol _|_ restecg, age, thalach | heartdisease, trestbps, sex, fbs, exang)
# (chol _|_ restecg, thalach, trestbps | heartdisease, age, sex, fbs, exang)
# (chol _|_ exang | thalach, trestbps, age, sex, fbs)
# (chol _|_ sex | thalach, trestbps, age, fbs, exang)
# (chol _|_ age | thalach, trestbps, sex, fbs, exang)
# (chol _|_ fbs, exang | restecg, heartdisease, thalach, trestbps, age, sex)
# (chol _|_ sex, exang | restecg, heartdisease, thalach, trestbps, age, fbs)
# (chol _|_ sex, fbs | restecg, heartdisease, thalach, trestbps, age, exang)
# (chol _|_ age, exang | restecg, heartdisease, thalach, trestbps, sex, fbs)
# (chol _|_ age, fbs | restecg, heartdisease, thalach, trestbps, sex, exang)
# (chol _|_ age, sex | restecg, heartdisease, thalach, trestbps, fbs, exang)
# (chol _|_ trestbps, exang | restecg, heartdisease, thalach, age, sex, fbs)
# (chol _|_ trestbps, fbs | restecg, heartdisease, thalach, age, sex, exang)
# (chol _|_ sex, trestbps | restecg, heartdisease, thalach, age, fbs, exang)
# (chol _|_ age, trestbps | restecg, heartdisease, thalach, sex, fbs, exang)
# (chol _|_ thalach, exang | restecg, heartdisease, trestbps, age, sex, fbs)
# (chol _|_ thalach, fbs | restecg, heartdisease, trestbps, age, sex, exang)
# (chol _|_ thalach, sex | restecg, heartdisease, trestbps, age, fbs, exang)
# (chol _|_ thalach, age | restecg, heartdisease, trestbps, sex, fbs, exang)
# (chol _|_ thalach, trestbps | restecg, heartdisease, age, sex, fbs, exang)
# (chol _|_ exang | restecg, thalach, trestbps, age, sex, fbs)
# (chol _|_ sex | restecg, thalach, trestbps, age, fbs, exang)
# (chol _|_ age | restecg, thalach, trestbps, sex, fbs, exang)
# (chol _|_ restecg, exang | heartdisease, thalach, trestbps, age, sex, fbs)
# (chol _|_ restecg, fbs | heartdisease, thalach, trestbps, age, sex, exang)
# (chol _|_ restecg, sex | heartdisease, thalach, trestbps, age, fbs, exang)
# (chol _|_ restecg, age | heartdisease, thalach, trestbps, sex, fbs, exang)
# (chol _|_ restecg, trestbps | heartdisease, thalach, age, sex, fbs, exang)
# (chol _|_ restecg, thalach | heartdisease, trestbps, age, sex, fbs, exang)
# (chol _|_ exang | restecg, heartdisease, thalach, trestbps, age, sex, fbs)
# (chol _|_ fbs | restecg, heartdisease, thalach, trestbps, age, sex, exang)
# (chol _|_ sex | restecg, heartdisease, thalach, trestbps, age, fbs, exang)
# (chol _|_ age | restecg, heartdisease, thalach, trestbps, sex, fbs, exang)
# (chol _|_ trestbps | restecg, heartdisease, thalach, age, sex, fbs, exang)
# (chol _|_ thalach | restecg, heartdisease, trestbps, age, sex, fbs, exang)
# (chol _|_ restecg | heartdisease, thalach, trestbps, age, sex, fbs, exang)

# %%
#Inferencing with Bayesian Network
# Doing exact inference using Variable Elimination
from pgmpy.inference import VariableElimination
HeartDisease_infer = VariableElimination(model)

# Computing the probability of bronc given smoke.
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print("Probability of gettting heart disease with the evidence age 28:\n ")
print(q['heartdisease'])

q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'chol': 100})
print("Probability of gettting heart disease with the evidence Cholestrol 100:\n ")
print(q['heartdisease'])
# Out:
# Probability of gettting heart disease with the evidence age 28:
#
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5897 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4103 │
# ╘════════════════╧═════════════════════╛
# Probability of gettting heart disease with the evidence Cholestrol 100:
#
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.6013 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.3987 │
# ╘════════════════╧═════════════════════╛
